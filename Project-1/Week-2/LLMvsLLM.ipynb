# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display, update_display
from litellm import completion

# %%
load_dotenv(override=True)
google_api_key=os.getenv('GOOGLE_API_KEY')
openai_api_key=os.getenv('OPENAI_API_KEY')
groq_api_key=os.getenv('GROQ_API_KEY')
if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")
if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
if groq_api_key:
    print(f"Groq API key exists and begins {groq_api_key[:3]}")
else:
    print("Groq API Key not set")
# Out:
# Google API Key exists and begins AI
# OpenAI API Key exists and begins sk-proj-
# Groq API key exists and begins gsk

# %%
gemini_sys_prompt="""you are very polite, courteous chatbot. who is very obliged and genuine. \
And try to find common ground in conflicts. If the other person is argumentative, \
you try to calm them down and keep chatting."""
gpt_sys_prompt="""you are a chatbot who is very argumentative; \ 
you disagree with anything in the conversation and you challenge everything, in a snarky way. """

# %%
def call_gemini():
    messages = [{"role" : "system", "content" : gemini_sys_prompt}]
    for gpt, gemini in zip(gpt_message, gemini_message):
        messages.append({"role" : "assistant", "content" : gemini})
        messages.append({"role" : "user", "content" : gpt})
    response = completion(model="gemini/gemini-2.5-flash", messages=messages)
    return response.choices[0].message.content

# %%
def call_gpt():
    messages = [{"role" : "system", "content" : gpt_sys_prompt}]
    for gpt, gemini in zip(gpt_message, gemini_message):
        messages.append({"role" : "assistant", "content" : gpt})
        messages.append({"role" : "user", "content" : gemini})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = completion(model="openai/gpt-4.1", messages=messages)
    return response.choices[0].message.content

# %%
gpt_messages = ["Hi There"]
gemini_messages = ["Hi "]

display(Markdown(f"### Gemini:\n{gemini_messages[0]}\n"))
display(Markdown(f"### GPT: \n {gpt_messages[0]} \n"))

for i in range(5):
    display(Markdown(f"### Gemini: \n"))
    gemini_next = call_gemini()
    display(Markdown(gemini_next))
    gemini_messages.append(gemini_next)
    
    display(Markdown(f"### GPT: \n"))
    gpt_next = call_gpt()
    display(Markdown(gpt_next))
    gpt_messages.append(gpt_next)
# Out:
# ### Gemini:
# Hi
# ### GPT:
#  Hi There
# ### Gemini:
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\litellm\llms\vertex_ai\gemini\vertex_and_google_ai_studio_gemini.py:2555, in VertexLLM.completion(self, model, messages, model_response, print_verbose, custom_llm_provider, encoding, logging_obj, optional_params, acompletion, timeout, vertex_project, vertex_location, vertex_credentials, gemini_api_key, litellm_params, logger_fn, extra_headers, client, api_base)
#    2554 try:
# -> 2555     response = client.post(url=url, headers=headers, json=data, logging_obj=logging_obj)  # type: ignore
#    2556     response.raise_for_status()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\litellm\llms\custom_httpx\http_handler.py:979, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     978     setattr(e, "status_code", e.response.status_code)
# --> 979     raise e
#     980 except Exception as e:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\litellm\llms\custom_httpx\http_handler.py:961, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     960 response = self.client.send(req, stream=stream)
# --> 961 response.raise_for_status()
#     962 return response
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\httpx\_models.py:749, in Response.raise_for_status(self)
#     748 message = message.format(self, error_type=error_type)
# --> 749 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Server error '503 Service Unavailable' for url 'https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?key=AIzaSyAkMTi1jl06oN_bfeLk2BSfMH92Qds2a8A'
# For more information check: https://httpstatuses.com/503
#
# During handling of the above exception, another exception occurred:
#
# VertexAIError                             Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\litellm\main.py:3110, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, verbosity, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    3109     new_params = safe_deep_copy(optional_params or {})
# -> 3110     response = vertex_chat_completion.completion(  # type: ignore
#    3111         model=model,
#    3112         messages=messages,
#    3113         model_response=model_response,
#    3114         print_verbose=print_verbose,
#    3115         optional_params=new_params,
#    3116         litellm_params=litellm_params,  # type: ignore
#    3117         logger_fn=logger_fn,
#    3118         encoding=encoding,
#    3119         vertex_location=vertex_ai_location,
#    3120         vertex_project=vertex_ai_project,
#    3121         vertex_credentials=vertex_credentials,
#    3122         gemini_api_key=gemini_api_key,
#    3123         logging_obj=logging,
#    3124         acompletion=acompletion,
#    3125         timeout=timeout,
#    3126         custom_llm_provider=custom_llm_provider,  # type: ignore
#    3127         client=client,
#    3128         api_base=api_base,
#    3129         extra_headers=headers,
#    3130     )
#    3132 elif custom_llm_provider == "vertex_ai":
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\litellm\llms\vertex_ai\gemini\vertex_and_google_ai_studio_gemini.py:2559, in VertexLLM.completion(self, model, messages, model_response, print_verbose, custom_llm_provider, encoding, logging_obj, optional_params, acompletion, timeout, vertex_project, vertex_location, vertex_credentials, gemini_api_key, litellm_params, logger_fn, extra_headers, client, api_base)
#    2558     error_code = err.response.status_code
# -> 2559     raise VertexAIError(
#    2560         status_code=error_code,
#    2561         message=err.response.text,
#    2562         headers=err.response.headers,
#    2563     )
#    2564 except httpx.TimeoutException:
#
# VertexAIError: {
#   "error": {
#     "code": 503,
#     "message": "The model is overloaded. Please try again later.",
#     "status": "UNAVAILABLE"
#   }
# }
#
#
# During handling of the above exception, another exception occurred:
#
# InternalServerError                       Traceback (most recent call last)
# Cell In[34], line 9
#       7 for i in range(5):
#       8     display(Markdown(f"### Gemini: \n"))
# ----> 9     gemini_next = call_gemini()
#      10     display(Markdown(gemini_next))
#      11     gemini_messages.append(gemini_next)
#
# Cell In[9], line 6, in call_gemini()
#       4     messages.append({"role" : "assistant", "content" : gemini})
#       5     messages.append({"role" : "user", "content" : gpt})
# ----> 6 response = completion(model="gemini/gemini-2.5-flash", messages=messages)
#       7 return response.choices[0].message.content
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\litellm\utils.py:1385, in client.<locals>.wrapper(*args, **kwargs)
#    1381 if logging_obj:
#    1382     logging_obj.failure_handler(
#    1383         e, traceback_exception, start_time, end_time
#    1384     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1385 raise e
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\litellm\utils.py:1254, in client.<locals>.wrapper(*args, **kwargs)
#    1252         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1253 # MODEL CALL
# -> 1254 result = original_function(*args, **kwargs)
#    1255 end_time = datetime.datetime.now()
#    1256 if _is_streaming_request(
#    1257     kwargs=kwargs,
#    1258     call_type=call_type,
#    1259 ):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\litellm\main.py:4046, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, verbosity, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    4043     return response
#    4044 except Exception as e:
#    4045     ## Map to OpenAI Exception
# -> 4046     raise exception_type(
#    4047         model=model,
#    4048         custom_llm_provider=custom_llm_provider,
#    4049         original_exception=e,
#    4050         completion_kwargs=args,
#    4051         extra_kwargs=kwargs,
#    4052     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2340, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2338 if exception_mapping_worked:
#    2339     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2340     raise e
#    2341 else:
#    2342     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:1350, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    1345 elif (
#    1346     "500 Internal Server Error" in error_str
#    1347     or "The model is overloaded." in error_str
#    1348 ):
#    1349     exception_mapping_worked = True
# -> 1350     raise litellm.InternalServerError(
#    1351         message=f"litellm.InternalServerError: {custom_llm_provider}Exception - {error_str}",
#    1352         model=model,
#    1353         llm_provider=custom_llm_provider,
#    1354         litellm_debug_info=extra_information,
#    1355     )
#    1356 if hasattr(original_exception, "status_code"):
#    1357     if original_exception.status_code == 400:
#
# InternalServerError: litellm.InternalServerError: litellm.InternalServerError: geminiException - {
#   "error": {
#     "code": 503,
#     "message": "The model is overloaded. Please try again later.",
#     "status": "UNAVAILABLE"
#   }
# }

# %%
for i in range(5):
    gemini_next = call_gemini()
    display(Markdown(f"## GPT:\n {gemini_next} \n"))
    gemini_message.append(gemini_next)

    gpt_next=call_gpt()
